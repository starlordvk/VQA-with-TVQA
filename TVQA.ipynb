# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# %cd "/content/gdrive/MyDrive/TVQA_test/TVQA"
# Out:
# /content/gdrive/.shortcut-targets-by-id/1Hof1M7LWgKQHM6s0-tt3R-5PYO5WK_k7/TVQA_test/TVQA

# %%
# !curl https://download.pytorch.org/whl/cu92/torch-1.2.0%2Bcu92-cp27-cp27mu-manylinux1_x86_64.whl --output torch-1.2.0%2Bcu92-cp27-cp27mu-manylinux1_x86_64.whl
# !python2 get-pip.py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.5 MB 16.3 MB/s
# ...
#      |████████████████████████████████| 583 kB 75.0 MB/s
# ...

# %%
# !pip2 install --upgrade pip
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already up-to-date: pip in /usr/local/lib/python2.7/dist-packages (20.3.4)

# %%
# ! pip2 install torch==1.10.1+cu113 -f https://download.pytorch.org/whl/torch_stable.html
! pip2 install torch-0.4.0-cp27-cp27mu-linux_x86_64.whl
! pip2 install /content/gdrive/MyDrive/TVQA_test/TVQA/torch-1.2.0%2Bcu92-cp27-cp27mu-manylinux1_x86_64.whl
! pip2 install tensorboardX==2.0.0
! pip2 install pysrt
! pip2 install h5py
! pip2 install tqdm
! pip2 install numpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing ./torch-0.4.0-cp27-cp27mu-linux_x86_64.whl
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.2.0+cu92
#     Uninstalling torch-1.2.0+cu92:
#       Successfully uninstalled torch-1.2.0+cu92
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/gdrive/MyDrive/TVQA_test/TVQA/torch-1.2.0%2Bcu92-cp27-cp27mu-manylinux1_x86_64.whl
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 0.4.0
#     Uninstalling torch-0.4.0:
#       Successfully uninstalled torch-0.4.0
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python2 test_file_cuda.py
# Out:
# python2: can't open file 'test_file_cuda.py': [Errno 2] No such file or directory

# %%
# !nvidia-smi -r
# Out:
# GPU 00000000:00:04.0 is currently in use by another process.
#
# 1 device is currently being used by one or more other processes (e.g., Fabric Manager, CUDA application, graphics application such as an X server, or a monitoring application such as another instance of nvidia-smi). Please first kill all processes using this device and all compute applications running in the system.

# %%
! python2 tvqa_dataset.py --
# Out:
# python2: can't open file 'tvqa_dataset.py': [Errno 2] No such file or directory

# %%
# !pip3 install tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 125 kB 4.7 MB/s
# ...

# %%
# !python2 main.py --input_streams sub vcpt
# Out:
# python2: can't open file 'main.py': [Errno 2] No such file or directory

# %%
! nvidia-smi -q -i 0

# %%
! pip2 install tensorboardX==2.0.0
# Out:
# /bin/bash: pip2: command not found

# %%
# !python2 test.py --model_dir /content/gdrive/MyDrive/TVQA_test/TVQA/results/results_2022_10_23_20_43_01/  --mode valid
# Out:
# Loading cache ...
# activate sub stream
# activate vcpt stream
# 153it [01:25,  1.79it/s]
# In valid mode, accuracy is 0.6898

# %%
import json
# Opening JSON file
f = open('/content/gdrive/MyDrive/TVQA_test/TVQA/results/results_2022_10_23_20_43_01/qid2preds_valid.json')
  
# returns JSON object as 
# a dictionary
pred = json.load(f)

# %%
len(pred)
# Out:
# 221
